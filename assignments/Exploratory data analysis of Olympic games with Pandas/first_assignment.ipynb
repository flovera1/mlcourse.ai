# %%
import pandas as pd

# %%
PATH = './data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# 1. How old were the youngest male and female participants of the 1996 Olympics?

# %%
ndata = data[data['Year'] == 1996]
ndata[ndata['Sex'] == "M"].sort_values(by='Age', ascending=True).head() # this shows the man would be 14 years old
# Out:
#            ID                  Name Sex   Age  Height  Weight         Team  \
# 87416   44326       Gwon Gyeong-Min   M  14.0   165.0    60.0  South Korea
# 170448  85647                Ng Sui   M  15.0     NaN     NaN    Hong Kong
# 139132  69887  Keng Liat "Alex" Lim   M  15.0   178.0    63.0     Malaysia
# 139133  69887  Keng Liat "Alex" Lim   M  15.0   178.0    63.0     Malaysia
# 80392   40801       Daniel A. Glomb   M  15.0   178.0    80.0       Brazil
#
#         NOC        Games  Year  Season     City     Sport  \
# 87416   KOR  1996 Summer  1996  Summer  Atlanta    Diving
# 170448  HKG  1996 Summer  1996  Summer  Atlanta    Diving
# 139132  MAS  1996 Summer  1996  Summer  Atlanta  Swimming
# 139133  MAS  1996 Summer  1996  Summer  Atlanta  Swimming
# 80392   BRA  1996 Summer  1996  Summer  Atlanta   Sailing
#
#                                        Event Medal
# 87416                  Diving Men's Platform   NaN
# 170448                 Diving Men's Platform   NaN
# ...

# %%
# 2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.

# %%
n2data = data[data['Year'] == 2000]
n2data.drop_duplicates(inplace=False).info() # 100% is 13821. 13821 are females and males
n2data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13821 entries, 31 to 271108
# Data columns (total 15 columns):
# ID        13821 non-null int64
# Name      13821 non-null object
# Sex       13821 non-null object
# Age       13820 non-null float64
# Height    13698 non-null float64
# Weight    13695 non-null float64
# Team      13821 non-null object
# NOC       13821 non-null object
# Games     13821 non-null object
# Year      13821 non-null int64
# Season    13821 non-null object
# City      13821 non-null object
# Sport     13821 non-null object
# Event     13821 non-null object
# Medal     2004 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.7+ MB
#             ID                                       Name Sex   Age  Height  \
# 31          12                          Jyri Tapani Aalto   M  31.0   172.0
# 33          13                         Minna Maarit Aalto   F  34.0   159.0
# ...

# %%
n3data = n2data[n2data['Sex'] == "M"].drop_duplicates(inplace=False)
n3data.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 31   12     Jyri Tapani Aalto   M  31.0   172.0    70.0      Finland  FIN
# 57   18  Timo Antero Aaltonen   M  31.0   189.0   130.0      Finland  FIN
# 81   23           Fritz Aanes   M  22.0   187.0    89.0       Norway  NOR
# 93   30      Pepijn Aardewijn   M  30.0   189.0    72.0  Netherlands  NED
# 103  36  Stefan Remco Aartsen   M  25.0   194.0    78.0  Netherlands  NED
#
#            Games  Year  Season    City      Sport  \
# 31   2000 Summer  2000  Summer  Sydney  Badminton
# 57   2000 Summer  2000  Summer  Sydney  Athletics
# 81   2000 Summer  2000  Summer  Sydney  Wrestling
# 93   2000 Summer  2000  Summer  Sydney     Rowing
# 103  2000 Summer  2000  Summer  Sydney   Swimming
#
#                                               Event Medal
# 31                          Badminton Men's Singles   NaN
# 57                         Athletics Men's Shot Put   NaN
# ...

# %%
n3data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8390 entries, 31 to 271108
# Data columns (total 15 columns):
# ID        8390 non-null int64
# Name      8390 non-null object
# Sex       8390 non-null object
# Age       8390 non-null float64
# Height    8310 non-null float64
# Weight    8308 non-null float64
# Team      8390 non-null object
# NOC       8390 non-null object
# Games     8390 non-null object
# Year      8390 non-null int64
# Season    8390 non-null object
# City      8390 non-null object
# Sport     8390 non-null object
# Event     8390 non-null object
# Medal     1124 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
# calculate the ratio
(8390 * 100) / 13821
# Out:
# 60.70472469430577

# %%
#3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.

# %%
n4data = data[data['Year'] == 2000]
n4data = n4data[n2data['Sex'] == "F"]
n4data["Height"].mean()
# Out:
# 168.97290274684485

# %%
n4data["Height"].std()
# Out:
# 9.460831918913273

# %%
# 4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?

# %%
n5data = data[data['Year'] == 2002]
n5data.sort_values(by='Weight', ascending=False).head() # this shows the man would be 14 years old
# Out:
#             ID               Name Sex   Age  Height  Weight  \
# 99154    50171  Emmanuel Hostache   M  26.0   190.0   123.0
# 129595   65246        Kevin Kuske   M  23.0   196.0   116.0
# 270556  135315      Zsolt Zsombor   M  30.0   193.0   115.0
# 60488    30980        Dalibor uri   M  26.0   196.0   113.0
# 128125   64528       Pavel Kubina   M  24.0   196.0   113.0
#
#                          Team  NOC        Games  Year  Season            City  \
# 99154                  France  FRA  2002 Winter  2002  Winter  Salt Lake City
# 129595              Germany-2  GER  2002 Winter  2002  Winter  Salt Lake City
# 270556                Hungary  HUN  2002 Winter  2002  Winter  Salt Lake City
# 60488   Serbia and Montenegro  SCG  2002 Winter  2002  Winter  Salt Lake City
# 128125         Czech Republic  CZE  2002 Winter  2002  Winter  Salt Lake City
#
#              Sport                        Event Medal
# 99154    Bobsleigh          Bobsleigh Men's Two   NaN
# ...

# %%
#5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?

# %%
data[data["Name"] == "Pawe Abratkiewicz"] # only three are different
# Out:
#        ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 997   562  Pawe Abratkiewicz   M  21.0   183.0    84.0  Poland  POL
# 998   562  Pawe Abratkiewicz   M  21.0   183.0    84.0  Poland  POL
# 999   562  Pawe Abratkiewicz   M  27.0   183.0    84.0  Poland  POL
# 1000  562  Pawe Abratkiewicz   M  27.0   183.0    84.0  Poland  POL
# 1001  562  Pawe Abratkiewicz   M  31.0   183.0    84.0  Poland  POL
# 1002  562  Pawe Abratkiewicz   M  31.0   183.0    84.0  Poland  POL
#
#             Games  Year  Season            City          Sport  \
# 997   1992 Winter  1992  Winter     Albertville  Speed Skating
# 998   1992 Winter  1992  Winter     Albertville  Speed Skating
# 999   1998 Winter  1998  Winter          Nagano  Speed Skating
# 1000  1998 Winter  1998  Winter          Nagano  Speed Skating
# 1001  2002 Winter  2002  Winter  Salt Lake City  Speed Skating
# 1002  2002 Winter  2002  Winter  Salt Lake City  Speed Skating
#
# ...

# %%
# 6. How many silver medals in tennis did Australia win at the 2000 Olympics?

# %%
n6data = data[data["Year"] == 2000]
n6data = n6data[n6data["Medal"] == "Silver"]
n6data = n6data[n6data["Sport"] == "Tennis"]
n6data = n6data[n6data["Team"] == "Australia"]
n6data # 2 medals
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %%
# 7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in Medal column.

# %%
n6data = data[data["Year"] == 2016]
n6data = n6data[n6data["Team"] == "Switzerland"]
n6data.dropna().info() # they got 11
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 12203 to 242890
# Data columns (total 15 columns):
# ID        11 non-null int64
# Name      11 non-null object
# Sex       11 non-null object
# Age       11 non-null float64
# Height    11 non-null float64
# Weight    11 non-null float64
# Team      11 non-null object
# NOC       11 non-null object
# Games     11 non-null object
# Year      11 non-null int64
# Season    11 non-null object
# City      11 non-null object
# Sport     11 non-null object
# Event     11 non-null object
# Medal     11 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.4+ KB

# %%
n7data = data[data["Year"] == 2016]
n7data = n7data[n7data["Team"] == "Serbia"]
n7data.dropna().info() # they got 54
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 4417 to 270370
# Data columns (total 15 columns):
# ID        54 non-null int64
# Name      54 non-null object
# Sex       54 non-null object
# Age       54 non-null float64
# Height    54 non-null float64
# Weight    54 non-null float64
# Team      54 non-null object
# NOC       54 non-null object
# Games     54 non-null object
# Year      54 non-null int64
# Season    54 non-null object
# City      54 non-null object
# Sport     54 non-null object
# Event     54 non-null object
# Medal     54 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 6.8+ KB

# %%
# Serbia won more medals than Switzerland in the Olympics of 2016
# So it's true that they won less medals.

# %%
#8. What age category did the fewest and the most participants of the 2014 Olympics belong to?

# %%
n8data = data[data["Year"] == 2014]

# %%
# 9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?

# %%
n9data = data[data["City"] == "Lake Placid"]
n9data = n9data[n9data["Season"] == "Summer"]
n9data.info() # no, it's not true, there were no Summer Olympics held in Lake Placid
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
# ID        0 non-null int64
# Name      0 non-null object
# Sex       0 non-null object
# Age       0 non-null float64
# Height    0 non-null float64
# Weight    0 non-null float64
# Team      0 non-null object
# NOC       0 non-null object
# Games     0 non-null object
# Year      0 non-null int64
# Season    0 non-null object
# City      0 non-null object
# Sport     0 non-null object
# Event     0 non-null object
# Medal     0 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 0.0+ bytes

# %%
n10data = data[data["City"] == "Sankt Moritz"]
n10data = n10data[n10data["Season"] == "Winter"]
n10data.info() # yes, it's true, there were winter Olympics held in Sankt Moritz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1657 entries, 935 to 270882
# Data columns (total 15 columns):
# ID        1657 non-null int64
# Name      1657 non-null object
# Sex       1657 non-null object
# Age       1563 non-null float64
# Height    238 non-null float64
# Weight    159 non-null float64
# Team      1657 non-null object
# NOC       1657 non-null object
# Games     1657 non-null object
# Year      1657 non-null int64
# Season    1657 non-null object
# City      1657 non-null object
# Sport     1657 non-null object
# Event     1657 non-null object
# Medal     224 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 207.1+ KB

# %%
# 10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?

# %%
n11data = data[data["Year"] == 2016]
n11data.Sport.unique() #36
# Out:
# array(['Weightlifting', 'Gymnastics', 'Athletics', 'Rowing', 'Taekwondo',
#        'Handball', 'Boxing', 'Equestrianism', 'Cycling', 'Volleyball',
#        'Diving', 'Shooting', 'Judo', 'Football', 'Synchronized Swimming',
#        'Wrestling', 'Fencing', 'Swimming', 'Badminton', 'Rugby Sevens',
#        'Table Tennis', 'Water Polo', 'Trampolining', 'Basketball',
#        'Triathlon', 'Modern Pentathlon', 'Sailing', 'Beach Volleyball',
#        'Golf', 'Rhythmic Gymnastics', 'Archery', 'Hockey', 'Canoeing',
#        'Tennis'], dtype=object)

# %%
n12data = data[data["Year"] == 1996]

# %%
n12data
# Out:
#             ID                                       Name Sex   Age  Height  \
# 32          13                         Minna Maarit Aalto   F  30.0   159.0
# 92          30                           Pepijn Aardewijn   M  26.0   189.0
# 97          33                        Mika Lauri Aarnikka   M  28.0   187.0
# 100         36                       Stefan Remco Aartsen   M  21.0   194.0
# 101         36                       Stefan Remco Aartsen   M  21.0   194.0
# 102         36                       Stefan Remco Aartsen   M  21.0   194.0
# 105         37                         Ann Kristin Aarnes   F  23.0   182.0
# 138         50                                 Arvi Aavik   M  26.0   185.0
# 180         78                               Salim Abanoz   M  26.0     NaN
# 182         80                     Jos Mara Abarca Plotas   M  22.0   186.0
# 219        106                         Agostino Abbagnale   M  29.0   188.0
# ...
